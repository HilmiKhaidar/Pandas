# %%
import pandas as pd

#NO 1 
data = pd.read_csv('data.csv')  
data
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 238  239             32    JAWA BARAT                 3275
# 239  240             32    JAWA BARAT                 3276
# 240  241             32    JAWA BARAT                 3277
# 241  242             32    JAWA BARAT                 3278
# 242  243             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# ...

# %%
# NO 2
# membuat dataFrame
df = pd.DataFrame(data)

# menghitung total produksi sampah untuk tahun tertentu
tahun_tertentu = 2018  # disini kita bebas untuk memasukan tahun yang kita / saya inginkan
total_sampah = 0

# terus ini untuk yang menggunakan itterrows
for index, row in df.iterrows():
    if row['tahun'] == tahun_tertentu:
        total_sampah += row['jumlah_produksi_sampah']

# untuk menghasilkan outputnya
print(f"Total produksi sampah di Jawa Barat pada tahun {tahun_tertentu}: {total_sampah} ton")
# Out:
# Total produksi sampah di Jawa Barat pada tahun 2015: 20969.269999999997 ton

# %%
# jumlah data pertahun menggunakan itterrows
total_per_tahun = {}
for index, row in df.iterrows():
    tahun = row['tahun']
    jumlah_sampah = row['jumlah_produksi_sampah']
    
    if tahun not in total_per_tahun:
        total_per_tahun[tahun] = 0
    total_per_tahun[tahun] += jumlah_sampah

# untuk menghasilkan output
for tahun, total_sampah in total_per_tahun.items():
    print(f"Tahun {tahun}: {total_sampah} ton")
# Out:
# Tahun 2015: 20969.269999999997 ton
# Tahun 2016: 20969.269999999997 ton
# Tahun 2017: 20969.269999999997 ton
# Tahun 2018: 22772.92 ton
# Tahun 2019: 24490.559999999998 ton
# Tahun 2020: 25333.0 ton
# Tahun 2021: 15735.360000000002 ton
# Tahun 2022: nan ton
# Tahun 2023: nan ton

# %%
# jadi di bagian ini untuk menginisialisasi dictionary untuk menyimpan total per kota / kabupaten dan tahun
total_per_kota_tahun = {}

# iterasi menggunakan iterrows
for index, row in df.iterrows():
    kota = row['nama_kabupaten_kota']
    tahun = row['tahun']
    jumlah_sampah = row['jumlah_produksi_sampah']
    
    if (kota, tahun) not in total_per_kota_tahun:
        total_per_kota_tahun[(kota, tahun)] = 0
    total_per_kota_tahun[(kota, tahun)] += jumlah_sampah

# ini buat output
for (kota, tahun), total_sampah in total_per_kota_tahun.items():
    print(f"Kota/Kabupaten: {kota}, Tahun: {tahun}, Total Sampah: {total_sampah} ton")
# Out:
# Kota/Kabupaten: KABUPATEN BOGOR, Tahun: 2015, Total Sampah: 1511.15 ton
# Kota/Kabupaten: KABUPATEN SUKABUMI, Tahun: 2015, Total Sampah: 419.01 ton
# Kota/Kabupaten: KABUPATEN CIANJUR, Tahun: 2015, Total Sampah: 981.41 ton
# Kota/Kabupaten: KABUPATEN BANDUNG, Tahun: 2015, Total Sampah: 1895.94 ton
# Kota/Kabupaten: KABUPATEN GARUT, Tahun: 2015, Total Sampah: 464.74 ton
# Kota/Kabupaten: KABUPATEN TASIKMALAYA, Tahun: 2015, Total Sampah: 464.52 ton
# Kota/Kabupaten: KABUPATEN CIAMIS, Tahun: 2015, Total Sampah: 260.91 ton
# Kota/Kabupaten: KABUPATEN KUNINGAN, Tahun: 2015, Total Sampah: 251.7 ton
# Kota/Kabupaten: KABUPATEN CIREBON, Tahun: 2015, Total Sampah: 465.75 ton
# Kota/Kabupaten: KABUPATEN MAJALENGKA, Tahun: 2015, Total Sampah: 254.63 ton
# Kota/Kabupaten: KABUPATEN SUMEDANG, Tahun: 2015, Total Sampah: 237.96 ton
# Kota/Kabupaten: KABUPATEN INDRAMAYU, Tahun: 2015, Total Sampah: 613.18 ton
# Kota/Kabupaten: KABUPATEN SUBANG, Tahun: 2015, Total Sampah: 487.26 ton
# ...

# %%
result_df = pd.DataFrame(list(total_per_kota_tahun.items()), columns=['Kota/Tahun', 'Total Sampah'])

#  buat ekspor ke CSV 
result_df.to_csv('hasil.csv', index=False)

# ini untuk ekspor ke Excel 
result_df.to_excel('hasil.xlsx', index=False)
